# %% [markdown]
# ! Please DONT Run this Notebook Directly... It changes all the Dependencies....
#
# Activate the Environment for BleuRT first

# %%
from bleurt import score
import numpy as np

def compute_scores(preds, references):
    scores = scorer.score(candidates=preds, references=references)
    
    # Return corpus-level BLEURT as average
    return float(np.mean(scores))
# Out:
# 2025-11-25 19:54:56.164418: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-25 19:54:56.226557: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-25 19:54:58.558524: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
import os
print(os.getcwd())
# Out:
# /workspace/Approach0/thenlpresearcher/in22_gen_eng_mar_hin

# %%
scorer = score.BleurtScorer("../../../Approach2/shalaka/bleurt/bleurt_checkpoints/base-128/bleurt-base-128")
# Out:
# INFO:tensorflow:Reading checkpoint ../../../Approach2/shalaka/bleurt/bleurt_checkpoints/base-128/bleurt-base-128.
# INFO:tensorflow:Config file found, reading.
# INFO:tensorflow:Will load checkpoint bert_custom
# INFO:tensorflow:Loads full paths and checks that files exists.
# INFO:tensorflow:... name:bert_custom
# INFO:tensorflow:... vocab_file:vocab.txt
# INFO:tensorflow:... bert_config_file:bert_config.json
# INFO:tensorflow:... do_lower_case:True
# INFO:tensorflow:... max_seq_length:128
# INFO:tensorflow:Creating BLEURT scorer.
# INFO:tensorflow:Creating WordPiece tokenizer.
# INFO:tensorflow:WordPiece tokenizer instantiated.
# INFO:tensorflow:Creating Eager Mode predictor.
# INFO:tensorflow:Loading model.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764100504.519665   67275 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 12838 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:17:00.0, compute capability: 8.0
# I0000 00:00:1764100504.521984   67275 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 394 MB memory:  -> device: 1, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:31:00.0, compute capability: 8.0
# I0000 00:00:1764100504.523484   67275 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 12859 MB memory:  -> device: 2, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:4b:00.0, compute capability: 8.0
# I0000 00:00:1764100504.525327   67275 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 34008 MB memory:  -> device: 3, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:ca:00.0, compute capability: 8.0
# INFO:tensorflow:BLEURT initialized.
# INFO:tensorflow:BLEURT initialized.

# %%
bleurt = {}

# %% [markdown]
# ## Original

# %%
file_name = "original_outputs.csv"
mode="original"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                                  src  \
# 0  An appearance is a bunch of attributes related...
# 1  Ajanta, located in the Aurangabad District of ...
# 2  Body colour gets merged with the outer line, c...
# 3  Ashoka started making extensive use of stone f...
# 4  Potatoes mixed in masalas, coated in besan bat...
#
#                                       prediction_mar  \
# 0  दिसणे म्हणजे सेवेतील व्यक्तीशी संबंधित त्यांचे...
# 1  महाराष्ट्रातील औरंगाबाद जिल्ह्यात असलेल्या अजि...
# 2  शरीराचा रंग बाहेरील रेषेत विलीन होतो, ज्यामुळे...
# 3  अशोकाने शिल्पे आणि महान स्मारकांसाठी दगडाचा मो...
# 4  मसाल्यांमध्ये मिसळलेले बटाटे, बेसनच्या पिठात ल...
#
#                                       prediction_hin  \
# 0  उपस्थिति सेवा करने वाले व्यक्ति से संबंधित विश...
# 1  महाराष्ट्र के औरंगाबाद जिले में स्थित अजंता मे...
# 2  शरीर का रंग बाहरी रेखा के साथ मिल जाता है, जिस...
# 3  अशोक ने मूर्तियों और महान स्मारकों के लिए पत्थ...
# 4  मसालों में मिश्रित आलू, बेसन के घोल में लेपित ...
#
#                                               gt_mar  \
# 0  रूप म्हणजे, सेवेतील व्यक्तीशी संबंधित बूट, कपड...
# 1  महाराष्ट्राच्या औरंगाबाद जिल्ह्यातील अजिंठ्यात...
# 2  शारीर रंग बाह्यरेषेत विलीन होत असल्याने भरीवपण...
# 3  अशोकाने शिल्पकृती आणि मोठ्या वास्तूंसाठी दगडां...
# 4  मसाल्यांत मिसळलेले बटाटे बेसनाच्या पातळ पिठात ...
#
#                                               gt_hin
# 0  सेवा संबंधी लोगों के लिए भेष कई गुणों का संयोज...
# 1  महाराष्ट्र के औरंगाबाद जिले में स्थित अजंता मे...
# 2  विस्तार का असर बनाते हुए, शरीर का रंग बाहरी रे...
# 3  अशोक ने व्यापक रूप से मूर्तियों और शानदार स्मा...
# 4  महाराष्ट्र के इस स्वादिष्ट और प्रसिद्ध व्यंजन ...

# %%
translations = df['prediction_mar']
ref_gem = df['gt_mar']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 'original' Model:  0.17825191859446932

# %% [markdown]
# ## Only Punctuations

# %%
file_name = "with_outputs.csv"
mode="with"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                                  src  \
# 0  An appearance is a bunch of attributes related...
# 1  Ajanta, located in the Aurangabad District of ...
# 2  Body colour gets merged with the outer line, c...
# 3  Ashoka started making extensive use of stone f...
# 4  Potatoes mixed in masalas, coated in besan bat...
#
#                                       prediction_mar  \
# 0  देखावा म्हणजे सेवेतील व्यक्तीशी संबंधित अनेक व...
# 1  महाराष्ट्रातील औरंगाबाद जिल्ह्यात वसलेल्या अजि...
# 2  शरीराचा रंग बाहेरील रेषेत विलीन होतो, ज्यामुळे...
# 3  अशोकाने शिल्पे आणि महान स्मारकांसाठी दगडाचा मो...
# 4  मसाल्यांमध्ये मिसळलेले बटाटे, बेसनच्या पिठात ल...
#
#                                       prediction_hin  \
# 0  उपस्थिति सेवा करने वाले व्यक्ति से संबंधित विश...
# 1  महाराष्ट्र के औरंगाबाद जिले में स्थित अजंता मे...
# 2  शरीर का रंग बाहरी रेखा के साथ मिल जाता है, जिस...
# 3  अशोक ने मूर्तियों और महान स्मारकों के लिए पत्थ...
# 4  मसालों में मिश्रित आलू, बेसन के घोल में लेपित ...
#
#                                               gt_mar  \
# 0  रूप म्हणजे, सेवेतील व्यक्तीशी संबंधित बूट, कपड...
# 1  महाराष्ट्राच्या औरंगाबाद जिल्ह्यातील अजिंठ्यात...
# 2  शारीर रंग बाह्यरेषेत विलीन होत असल्याने भरीवपण...
# 3  अशोकाने शिल्पकृती आणि मोठ्या वास्तूंसाठी दगडां...
# 4  मसाल्यांत मिसळलेले बटाटे बेसनाच्या पातळ पिठात ...
#
#                                               gt_hin
# 0  सेवा संबंधी लोगों के लिए भेष कई गुणों का संयोज...
# 1  महाराष्ट्र के औरंगाबाद जिले में स्थित अजंता मे...
# 2  विस्तार का असर बनाते हुए, शरीर का रंग बाहरी रे...
# 3  अशोक ने व्यापक रूप से मूर्तियों और शानदार स्मा...
# 4  महाराष्ट्र के इस स्वादिष्ट और प्रसिद्ध व्यंजन ...

# %%
translations = df['prediction_mar']
ref_gem = df['gt_mar']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 'with' Model:  0.15496423965669237

# %% [markdown]
# ## Without Punctuations

# %%
file_name = "without_outputs.csv"
mode="without"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                                  src  \
# 0  An appearance is a bunch of attributes related...
# 1  Ajanta, located in the Aurangabad District of ...
# 2  Body colour gets merged with the outer line, c...
# 3  Ashoka started making extensive use of stone f...
# 4  Potatoes mixed in masalas, coated in besan bat...
#
#                                       prediction_mar  \
# 0  देखावा हा सेवा करणाऱ्या व्यक्तीशी संबंधित अनेक...
# 1  महाराष्ट्रातील औरंगाबाद जिल्ह्यात वसलेल्या अजि...
# 2  शरीराचा रंग बाह्य रेषेत विलीन होतो, ज्यामुळे आ...
# 3  अशोकाने शिल्पे आणि महान स्मारकांसाठी दगडाचा मो...
# 4  मसाल्यांमध्ये मिसळलेले बटाटे, बेसनच्या पिठात ल...
#
#                                       prediction_hin  \
# 0  उपस्थिति सेवा करने वाले व्यक्ति से संबंधित विश...
# 1  महाराष्ट्र के औरंगाबाद जिले में स्थित अजंता मे...
# 2  शरीर का रंग बाहरी रेखा के साथ मिल जाता है, जिस...
# 3  अशोक ने मूर्तियों और महान स्मारकों के लिए पत्थ...
# 4  मसालों में मिश्रित आलू, बेसन के घोल में लेपित ...
#
#                                               gt_mar  \
# 0  रूप म्हणजे, सेवेतील व्यक्तीशी संबंधित बूट, कपड...
# 1  महाराष्ट्राच्या औरंगाबाद जिल्ह्यातील अजिंठ्यात...
# 2  शारीर रंग बाह्यरेषेत विलीन होत असल्याने भरीवपण...
# 3  अशोकाने शिल्पकृती आणि मोठ्या वास्तूंसाठी दगडां...
# 4  मसाल्यांत मिसळलेले बटाटे बेसनाच्या पातळ पिठात ...
#
#                                               gt_hin
# 0  सेवा संबंधी लोगों के लिए भेष कई गुणों का संयोज...
# 1  महाराष्ट्र के औरंगाबाद जिले में स्थित अजंता मे...
# 2  विस्तार का असर बनाते हुए, शरीर का रंग बाहरी रे...
# 3  अशोक ने व्यापक रूप से मूर्तियों और शानदार स्मा...
# 4  महाराष्ट्र के इस स्वादिष्ट और प्रसिद्ध व्यंजन ...

# %%
translations = df['prediction_mar']
ref_gem = df['gt_mar']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 'without' Model:  0.1614281750516966

# %% [markdown]
# ## Combined- Shalaka LR=5e-6 Epochs=3

# %%
file_name = "combined_2x_outputs.csv"
mode="combined_2x"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                                  src  \
# 0  An appearance is a bunch of attributes related...
# 1  Ajanta, located in the Aurangabad District of ...
# 2  Body colour gets merged with the outer line, c...
# 3  Ashoka started making extensive use of stone f...
# 4  Potatoes mixed in masalas, coated in besan bat...
#
#                                       prediction_mar  \
# 0  दिसणे म्हणजे सेवेतील व्यक्तीशी संबंधित गुणधर्म...
# 1  महाराष्ट्रातील औरंगाबाद जिल्ह्यात असलेल्या अजि...
# 2  शरीराचा रंग बाहेरील रेषेमध्ये विलीन होतो, ज्या...
# 3  अशोकाने शिल्पे आणि महान स्मारकांसाठी दगडाचा मो...
# 4  मसाल्यांमध्ये मिसळलेले बटाटे, बेसनच्या पिठात ल...
#
#                                       prediction_hin  \
# 0  उपस्थिति सेवा करने वाले व्यक्ति से संबंधित विश...
# 1  महाराष्ट्र के औरंगाबाद जिले में स्थित अजंता मे...
# 2  शरीर का रंग बाहरी रेखा के साथ मिल जाता है, जिस...
# 3  अशोक ने मूर्तियों और महान स्मारकों के लिए पत्थ...
# 4  मसालों में मिश्रित आलू, बेसन के घोल में लेपित ...
#
#                                               gt_mar  \
# 0  रूप म्हणजे, सेवेतील व्यक्तीशी संबंधित बूट, कपड...
# 1  महाराष्ट्राच्या औरंगाबाद जिल्ह्यातील अजिंठ्यात...
# 2  शारीर रंग बाह्यरेषेत विलीन होत असल्याने भरीवपण...
# 3  अशोकाने शिल्पकृती आणि मोठ्या वास्तूंसाठी दगडां...
# 4  मसाल्यांत मिसळलेले बटाटे बेसनाच्या पातळ पिठात ...
#
#                                               gt_hin
# 0  सेवा संबंधी लोगों के लिए भेष कई गुणों का संयोज...
# 1  महाराष्ट्र के औरंगाबाद जिले में स्थित अजंता मे...
# 2  विस्तार का असर बनाते हुए, शरीर का रंग बाहरी रे...
# 3  अशोक ने व्यापक रूप से मूर्तियों और शानदार स्मा...
# 4  महाराष्ट्र के इस स्वादिष्ट और प्रसिद्ध व्यंजन ...

# %%
translations = df['prediction_mar']
ref_gem = df['gt_mar']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 'combined_2x' Model:  0.16055765806231648

# %% [markdown]
# ## Combined- Shalaka LR=5e-6 Epochs=3 Changed Dataset

# %%
file_name = "combined_x_outputs.csv"
mode="combined_x"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                                  src  \
# 0  An appearance is a bunch of attributes related...
# 1  Ajanta, located in the Aurangabad District of ...
# 2  Body colour gets merged with the outer line, c...
# 3  Ashoka started making extensive use of stone f...
# 4  Potatoes mixed in masalas, coated in besan bat...
#
#                                       prediction_mar  \
# 0  दिसणे म्हणजे सेवेतील व्यक्तीशी संबंधित गुणधर्म...
# 1  महाराष्ट्रातील औरंगाबाद जिल्ह्यात असलेल्या अजि...
# 2  शरीराचा रंग बाह्य रेषेत विलीन होतो, ज्यामुळे आ...
# 3  अशोकाने शिल्पे आणि महान स्मारकांसाठी दगडाचा व्...
# 4  मसाल्यांमध्ये मिसळलेले बटाटे, बेसनच्या पिठात ल...
#
#                                       prediction_hin  \
# 0  उपस्थिति सेवा करने वाले व्यक्ति से संबंधित विश...
# 1  महाराष्ट्र के औरंगाबाद जिले में स्थित अजंता मे...
# 2  शरीर का रंग बाहरी रेखा के साथ मिल जाता है, जिस...
# 3  अशोक ने मूर्तियों और महान स्मारकों के लिए पत्थ...
# 4  मसालों में मिश्रित आलू, बेसन के घोल में लेपित ...
#
#                                               gt_mar  \
# 0  रूप म्हणजे, सेवेतील व्यक्तीशी संबंधित बूट, कपड...
# 1  महाराष्ट्राच्या औरंगाबाद जिल्ह्यातील अजिंठ्यात...
# 2  शारीर रंग बाह्यरेषेत विलीन होत असल्याने भरीवपण...
# 3  अशोकाने शिल्पकृती आणि मोठ्या वास्तूंसाठी दगडां...
# 4  मसाल्यांत मिसळलेले बटाटे बेसनाच्या पातळ पिठात ...
#
#                                               gt_hin
# 0  सेवा संबंधी लोगों के लिए भेष कई गुणों का संयोज...
# 1  महाराष्ट्र के औरंगाबाद जिले में स्थित अजंता मे...
# 2  विस्तार का असर बनाते हुए, शरीर का रंग बाहरी रे...
# 3  अशोक ने व्यापक रूप से मूर्तियों और शानदार स्मा...
# 4  महाराष्ट्र के इस स्वादिष्ट और प्रसिद्ध व्यंजन ...

# %%
translations = df['prediction_mar']
ref_gem = df['gt_mar']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 'combined_x' Model:  0.16326732221568818

# %% [markdown]
# ## T5

# %%
file_name = "t5_outputs.csv"
mode="t5"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                                  src  \
# 0  An appearance is a bunch of attributes related...
# 1  Ajanta, located in the Aurangabad District of ...
# 2  Body colour gets merged with the outer line, c...
# 3  Ashoka started making extensive use of stone f...
# 4  Potatoes mixed in masalas, coated in besan bat...
#
#                                       prediction_mar  \
# 0  दिसणे म्हणजे सेवेतील व्यक्तीशी संबंधित गुणधर्म...
# 1  महाराष्ट्रातील औरंगाबाद जिल्ह्यात असलेल्या अजि...
# 2  शरीराचा रंग बाह्य रेषेत विलीन होतो, ज्यामुळे आ...
# 3  अशोकाने शिल्पे आणि महान स्मारकांसाठी दगडाचा व्...
# 4  मसाल्यांमध्ये मिसळलेले बटाटे, बेसनच्या पिठात ल...
#
#                                       prediction_hin  \
# 0  उपस्थिति सेवा करने वाले व्यक्ति से संबंधित विश...
# 1  महाराष्ट्र के औरंगाबाद जिले में स्थित अजंता मे...
# 2  शरीर का रंग बाहरी रेखा के साथ मिल जाता है, जिस...
# 3  अशोक ने मूर्तियों और महान स्मारकों के लिए पत्थ...
# 4  मसालों में मिश्रित आलू, बेसन के घोल में लेपित ...
#
#                                               gt_mar  \
# 0  रूप म्हणजे, सेवेतील व्यक्तीशी संबंधित बूट, कपड...
# 1  महाराष्ट्राच्या औरंगाबाद जिल्ह्यातील अजिंठ्यात...
# 2  शारीर रंग बाह्यरेषेत विलीन होत असल्याने भरीवपण...
# 3  अशोकाने शिल्पकृती आणि मोठ्या वास्तूंसाठी दगडां...
# 4  मसाल्यांत मिसळलेले बटाटे बेसनाच्या पातळ पिठात ...
#
#                                               gt_hin
# 0  सेवा संबंधी लोगों के लिए भेष कई गुणों का संयोज...
# 1  महाराष्ट्र के औरंगाबाद जिले में स्थित अजंता मे...
# 2  विस्तार का असर बनाते हुए, शरीर का रंग बाहरी रे...
# 3  अशोक ने व्यापक रूप से मूर्तियों और शानदार स्मा...
# 4  महाराष्ट्र के इस स्वादिष्ट और प्रसिद्ध व्यंजन ...

# %%
translations = df['prediction_mar']
ref_gem = df['gt_mar']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 't5' Model:  0.16216194996013655

# %%
for key, val in bleurt.items():
    print(f"{key} : {val:.4f}")
# Out:
# original : 0.1783
# with : 0.1550
# without : 0.1614
# combined_2x : 0.1606
# combined_x : 0.1633
# t5 : 0.1622
