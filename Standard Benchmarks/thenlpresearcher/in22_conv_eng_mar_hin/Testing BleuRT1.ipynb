# %% [markdown]
# ! Please DONT Run this Notebook Directly... It changes all the Dependencies....
#
# Activate the Environment for BleuRT first

# %%
from bleurt import score
import numpy as np

def compute_scores(preds, references):
    scores = scorer.score(candidates=preds, references=references)
    
    # Return corpus-level BLEURT as average
    return float(np.mean(scores))
# Out:
# 2025-11-25 19:41:56.443623: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-25 19:41:56.507206: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-25 19:41:58.765803: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
import os
print(os.getcwd())
# Out:
# /workspace/Approach0/thenlpresearcher/in22_conv_eng_mar_hin

# %%
scorer = score.BleurtScorer("../../../Approach2/shalaka/bleurt/bleurt_checkpoints/base-128/bleurt-base-128")
# Out:
# INFO:tensorflow:Reading checkpoint ../../../Approach2/shalaka/bleurt/bleurt_checkpoints/base-128/bleurt-base-128.
# INFO:tensorflow:Config file found, reading.
# INFO:tensorflow:Will load checkpoint bert_custom
# INFO:tensorflow:Loads full paths and checks that files exists.
# INFO:tensorflow:... name:bert_custom
# INFO:tensorflow:... vocab_file:vocab.txt
# INFO:tensorflow:... bert_config_file:bert_config.json
# INFO:tensorflow:... do_lower_case:True
# INFO:tensorflow:... max_seq_length:128
# INFO:tensorflow:Creating BLEURT scorer.
# INFO:tensorflow:Creating WordPiece tokenizer.
# INFO:tensorflow:WordPiece tokenizer instantiated.
# INFO:tensorflow:Creating Eager Mode predictor.
# INFO:tensorflow:Loading model.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764099725.519664   63531 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 64841 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:17:00.0, compute capability: 8.0
# I0000 00:00:1764099725.521374   63531 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 394 MB memory:  -> device: 1, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:31:00.0, compute capability: 8.0
# I0000 00:00:1764099725.522668   63531 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 12859 MB memory:  -> device: 2, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:4b:00.0, compute capability: 8.0
# I0000 00:00:1764099725.524668   63531 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 5789 MB memory:  -> device: 3, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:ca:00.0, compute capability: 8.0
# INFO:tensorflow:BLEURT initialized.
# INFO:tensorflow:BLEURT initialized.

# %%
bleurt = {}

# %% [markdown]
# ## Original

# %%
file_name = "original_outputs.csv"
mode="original"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                               src  \
# 0             Mom, let's go for a movie tomorrow.
# 1                   I don't have to go to school.
# 2                                It is a holiday.
# 3        Oh, tomorrow is the 14th of April right?
# 4  Your dad will also have the day off from work.
#
#                               prediction_mar  \
# 0                आई, उद्या चित्रपटाला जाऊया.
# 1               मला शाळेत जाण्याची गरज नाही.
# 2                            ती सुट्टी असते.
# 3               अरे, उद्या 14 एप्रिल आहे ना?
# 4  तुमच्या वडिलांनाही कामावरून सुट्टी मिळेल.
#
#                           prediction_hin  \
# 0  माँ, चलो कल एक फ़िल्म देखने चलते हैं।
# 1     मुझे स्कूल जाने की ज़रूरत नहीं है।
# 2                          यह छुट्टी है।
# 3                ओह, कल 14 अप्रैल है ना?
# 4  आपके पिता को भी काम से छुट्टी मिलेगी।
#
#                                       gt_mar  \
# 0   आई, उद्या आपण एखादा सिनेमा बघायला जाऊया.
# 1                    मला शाळेत जायचं नाहीये.
# 2                          उद्या सुट्टी आहे.
# 3                ओहो, उद्या १४ एप्रिल हो ना?
# 4  तुझ्या बाबांना सुद्धा उद्या सुट्टी राहील.
#
#                                   gt_hin
# 0   माँ, चलो कल एक फिल्म देखने चलते हैं।
# 1            मुझे कल स्कूल नहीं जाना है।
# 2                             छुट्टी है।
# 3                 ओह, कल 14 अप्रैल है न?
# 4  कल तुम्हारे पिताजी की भी छुट्टी होगी।

# %%
translations = df['prediction_mar']
ref_gem = df['gt_mar']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 'original' Model:  0.33059215609601394

# %% [markdown]
# ## Only Punctuations

# %%
file_name = "with_outputs.csv"
mode="with"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                               src  \
# 0             Mom, let's go for a movie tomorrow.
# 1                   I don't have to go to school.
# 2                                It is a holiday.
# 3        Oh, tomorrow is the 14th of April right?
# 4  Your dad will also have the day off from work.
#
#                               prediction_mar  \
# 0              आई, उद्या चित्रपट बघायला जाऊ.
# 1               मला शाळेत जाण्याची गरज नाही.
# 2                            ती सुट्टी असते.
# 3               अरे, उद्या 14 एप्रिल आहे ना?
# 4  तुमच्या वडिलांनाही कामावरून सुट्टी मिळेल.
#
#                           prediction_hin  \
# 0  माँ, चलो कल एक फ़िल्म देखने चलते हैं।
# 1     मुझे स्कूल जाने की ज़रूरत नहीं है।
# 2                          यह छुट्टी है।
# 3                ओह, कल 14 अप्रैल है ना?
# 4  आपके पिता को भी काम से छुट्टी मिलेगी।
#
#                                       gt_mar  \
# 0   आई, उद्या आपण एखादा सिनेमा बघायला जाऊया.
# 1                    मला शाळेत जायचं नाहीये.
# 2                          उद्या सुट्टी आहे.
# 3                ओहो, उद्या १४ एप्रिल हो ना?
# 4  तुझ्या बाबांना सुद्धा उद्या सुट्टी राहील.
#
#                                   gt_hin
# 0   माँ, चलो कल एक फिल्म देखने चलते हैं।
# 1            मुझे कल स्कूल नहीं जाना है।
# 2                             छुट्टी है।
# 3                 ओह, कल 14 अप्रैल है न?
# 4  कल तुम्हारे पिताजी की भी छुट्टी होगी।

# %%
translations = df['prediction_mar']
ref_gem = df['gt_mar']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 'with' Model:  0.2875443826927119

# %% [markdown]
# ## Without Punctuations

# %%
file_name = "without_outputs.csv"
mode="without"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                               src  \
# 0             Mom, let's go for a movie tomorrow.
# 1                   I don't have to go to school.
# 2                                It is a holiday.
# 3        Oh, tomorrow is the 14th of April right?
# 4  Your dad will also have the day off from work.
#
#                               prediction_mar  \
# 0              आई, उद्या चित्रपट बघायला जाऊ.
# 1                  मला शाळेत जायची गरज नाही.
# 2                            ती सुट्टी असते.
# 3               अरे, उद्या 14 एप्रिल आहे ना?
# 4  तुमच्या वडिलांनाही कामावरून सुट्टी मिळेल.
#
#                           prediction_hin  \
# 0  माँ, चलो कल एक फ़िल्म देखने चलते हैं।
# 1     मुझे स्कूल जाने की ज़रूरत नहीं है।
# 2                          यह छुट्टी है।
# 3                ओह, कल 14 अप्रैल है ना?
# 4  आपके पिता को भी काम से छुट्टी मिलेगी।
#
#                                       gt_mar  \
# 0   आई, उद्या आपण एखादा सिनेमा बघायला जाऊया.
# 1                    मला शाळेत जायचं नाहीये.
# 2                          उद्या सुट्टी आहे.
# 3                ओहो, उद्या १४ एप्रिल हो ना?
# 4  तुझ्या बाबांना सुद्धा उद्या सुट्टी राहील.
#
#                                   gt_hin
# 0   माँ, चलो कल एक फिल्म देखने चलते हैं।
# 1            मुझे कल स्कूल नहीं जाना है।
# 2                             छुट्टी है।
# 3                 ओह, कल 14 अप्रैल है न?
# 4  कल तुम्हारे पिताजी की भी छुट्टी होगी।

# %%
translations = df['prediction_mar']
ref_gem = df['gt_mar']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 'without' Model:  0.30764341935842576

# %% [markdown]
# ## Combined- Shalaka LR=5e-6 Epochs=3

# %%
file_name = "combined_2x_outputs.csv"
mode="combined_2x"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                               src  \
# 0             Mom, let's go for a movie tomorrow.
# 1                   I don't have to go to school.
# 2                                It is a holiday.
# 3        Oh, tomorrow is the 14th of April right?
# 4  Your dad will also have the day off from work.
#
#                               prediction_mar  \
# 0          आई, उद्या एखाद्या चित्रपटाला जाऊ.
# 1               मला शाळेत जाण्याची गरज नाही.
# 2                            ती सुट्टी असते.
# 3               अरे, उद्या 14 एप्रिल आहे ना?
# 4  तुमच्या वडिलांनाही कामावरून सुट्टी मिळेल.
#
#                           prediction_hin  \
# 0  माँ, चलो कल एक फ़िल्म देखने चलते हैं।
# 1     मुझे स्कूल जाने की ज़रूरत नहीं है।
# 2                          यह छुट्टी है।
# 3                ओह, कल 14 अप्रैल है ना?
# 4  आपके पिता को भी काम से छुट्टी मिलेगी।
#
#                                       gt_mar  \
# 0   आई, उद्या आपण एखादा सिनेमा बघायला जाऊया.
# 1                    मला शाळेत जायचं नाहीये.
# 2                          उद्या सुट्टी आहे.
# 3                ओहो, उद्या १४ एप्रिल हो ना?
# 4  तुझ्या बाबांना सुद्धा उद्या सुट्टी राहील.
#
#                                   gt_hin
# 0   माँ, चलो कल एक फिल्म देखने चलते हैं।
# 1            मुझे कल स्कूल नहीं जाना है।
# 2                             छुट्टी है।
# 3                 ओह, कल 14 अप्रैल है न?
# 4  कल तुम्हारे पिताजी की भी छुट्टी होगी।

# %%
translations = df['prediction_mar']
ref_gem = df['gt_mar']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 'combined_2x' Model:  0.3185298358940991

# %% [markdown]
# ## Combined- Shalaka LR=5e-6 Epochs=3 Changed Dataset

# %%
file_name = "combined_x_outputs.csv"
mode="combined_x"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                               src  \
# 0             Mom, let's go for a movie tomorrow.
# 1                   I don't have to go to school.
# 2                                It is a holiday.
# 3        Oh, tomorrow is the 14th of April right?
# 4  Your dad will also have the day off from work.
#
#                               prediction_mar  \
# 0          आई, उद्या एखाद्या चित्रपटाला जाऊ.
# 1               मला शाळेत जाण्याची गरज नाही.
# 2                            ती सुट्टी असते.
# 3               अरे, उद्या 14 एप्रिल आहे ना?
# 4  तुमच्या वडिलांनाही कामावरून सुट्टी मिळेल.
#
#                           prediction_hin  \
# 0  माँ, चलो कल एक फ़िल्म देखने चलते हैं।
# 1     मुझे स्कूल जाने की ज़रूरत नहीं है।
# 2                          यह छुट्टी है।
# 3                ओह, कल 14 अप्रैल है ना?
# 4  आपके पिता को भी काम से छुट्टी मिलेगी।
#
#                                       gt_mar  \
# 0   आई, उद्या आपण एखादा सिनेमा बघायला जाऊया.
# 1                    मला शाळेत जायचं नाहीये.
# 2                          उद्या सुट्टी आहे.
# 3                ओहो, उद्या १४ एप्रिल हो ना?
# 4  तुझ्या बाबांना सुद्धा उद्या सुट्टी राहील.
#
#                                   gt_hin
# 0   माँ, चलो कल एक फिल्म देखने चलते हैं।
# 1            मुझे कल स्कूल नहीं जाना है।
# 2                             छुट्टी है।
# 3                 ओह, कल 14 अप्रैल है न?
# 4  कल तुम्हारे पिताजी की भी छुट्टी होगी।

# %%
translations = df['prediction_mar']
ref_gem = df['gt_mar']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 'combined_x' Model:  0.3175089329218396

# %% [markdown]
# ## T5

# %%
file_name = "t5_outputs.csv"
mode="t5"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                               src  \
# 0             Mom, let's go for a movie tomorrow.
# 1                   I don't have to go to school.
# 2                                It is a holiday.
# 3        Oh, tomorrow is the 14th of April right?
# 4  Your dad will also have the day off from work.
#
#                               prediction_mar  \
# 0          आई, उद्या एखाद्या चित्रपटाला जाऊ.
# 1               मला शाळेत जाण्याची गरज नाही.
# 2                            ती सुट्टी असते.
# 3               अरे, उद्या 14 एप्रिल आहे ना?
# 4  तुमच्या वडिलांनाही कामावरून सुट्टी मिळेल.
#
#                           prediction_hin  \
# 0  माँ, चलो कल एक फ़िल्म देखने चलते हैं।
# 1     मुझे स्कूल जाने की ज़रूरत नहीं है।
# 2                          यह छुट्टी है।
# 3                ओह, कल 14 अप्रैल है ना?
# 4  आपके पिता को भी काम से छुट्टी मिलेगी।
#
#                                       gt_mar  \
# 0   आई, उद्या आपण एखादा सिनेमा बघायला जाऊया.
# 1                    मला शाळेत जायचं नाहीये.
# 2                          उद्या सुट्टी आहे.
# 3                ओहो, उद्या १४ एप्रिल हो ना?
# 4  तुझ्या बाबांना सुद्धा उद्या सुट्टी राहील.
#
#                                   gt_hin
# 0   माँ, चलो कल एक फिल्म देखने चलते हैं।
# 1            मुझे कल स्कूल नहीं जाना है।
# 2                             छुट्टी है।
# 3                 ओह, कल 14 अप्रैल है न?
# 4  कल तुम्हारे पिताजी की भी छुट्टी होगी।

# %%
translations = df['prediction_mar']
ref_gem = df['gt_mar']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 't5' Model:  0.3147960917148008

# %%
for key, val in bleurt.items():
    print(f"{key} : {val:.4f}")
# Out:
# original : 0.3306
# with : 0.2875
# without : 0.3076
# combined_2x : 0.3185
# combined_x : 0.3175
# t5 : 0.3148
