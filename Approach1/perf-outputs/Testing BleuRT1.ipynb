# %% [markdown]
# ! Please DONT Run this Notebook Directly... It changes all the Dependencies....
#
# Activate the Environment for BleuRT first

# %%
from bleurt import score
import numpy as np

def compute_scores(preds, references):
    scores = scorer.score(candidates=preds, references=references)
    
    # Return corpus-level BLEURT as average
    return float(np.mean(scores))
# Out:
# 2025-11-26 16:56:54.694779: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:56:54.760374: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-26 16:56:57.379168: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
import os
print(os.getcwd())
# Out:
# /workspace/Approach1/perf-outputs

# %%
scorer = score.BleurtScorer("../../Approach2/shalaka/bleurt/bleurt_checkpoints/base-128/bleurt-base-128")
# Out:
# INFO:tensorflow:Reading checkpoint ../../Approach2/shalaka/bleurt/bleurt_checkpoints/base-128/bleurt-base-128.
# INFO:tensorflow:Config file found, reading.
# INFO:tensorflow:Will load checkpoint bert_custom
# INFO:tensorflow:Loads full paths and checks that files exists.
# INFO:tensorflow:... name:bert_custom
# INFO:tensorflow:... vocab_file:vocab.txt
# INFO:tensorflow:... bert_config_file:bert_config.json
# INFO:tensorflow:... do_lower_case:True
# INFO:tensorflow:... max_seq_length:128
# INFO:tensorflow:Creating BLEURT scorer.
# INFO:tensorflow:Creating WordPiece tokenizer.
# INFO:tensorflow:WordPiece tokenizer instantiated.
# INFO:tensorflow:Creating Eager Mode predictor.
# INFO:tensorflow:Loading model.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764176226.787957   74927 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 70884 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:17:00.0, compute capability: 8.0
# I0000 00:00:1764176226.789991   74927 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 32101 MB memory:  -> device: 1, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:31:00.0, compute capability: 8.0
# I0000 00:00:1764176226.791354   74927 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 21892 MB memory:  -> device: 2, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:4b:00.0, compute capability: 8.0
# I0000 00:00:1764176226.792806   74927 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 28841 MB memory:  -> device: 3, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:ca:00.0, compute capability: 8.0
# INFO:tensorflow:BLEURT initialized.
# INFO:tensorflow:BLEURT initialized.

# %%
bleurt = {}

# %% [markdown]
# ## T5 Punctuation Restoration

# %%
file_name = "approach1_eng_to_eng_t5_outputs_punct_restor_data.csv"
mode="t5_punct"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                           prediction  \
# 0  Several years ago here at TED, Peter Skillman ...
# 1  And the ideas pretty simple: Teams of four hav...
# 2                  The marshmallow has to be on top.
# 3  And though it seems really simple, it's actual...
# 4  And so I thought this was an interesting idea,...
#
#                                                  src  \
# 0  Several years ago here at TED Peter Skillman  ...
# 1  And the ideas pretty simple  Teams of four hav...
# 2                   The marshmallow has to be on top
# 3  And though it seems really simple its actually...
# 4  And so I thought this was an interesting idea ...
#
#                                                   gt
# 0  Several years ago here at TED, Peter Skillman ...
# 1  And the idea's pretty simple:  Teams of four h...
# 2                  The marshmallow has to be on top.
# 3  And, though it seems really simple, it's actua...
# 4  And so, I thought this was an interesting idea...

# %%
translations = df['prediction']
ref_gem = df['gt']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 't5_punct' Model:  0.8838027026225308

# %% [markdown]
# ## T5 Seq-to-Seq

# %%
file_name = "approach1_eng_to_eng_t5_outputs_mar_data.csv"
mode="t5"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                           prediction  \
# 0  Chanting, the choir raised the volume as the c...
# 1  A six-month-old calf was submitted for examina...
# 2  Planning authorities should provide alternativ...
# 3  As the machine develops, the forms we use to r...
# 4  As mentioned, first impressions can be mislead...
#
#                                                  src  \
# 0  Chanting the choir raised the volume as the ce...
# 1  A six-month-old calf was submitted for examina...
# 2  Planning authorities should provide alternativ...
# 3  As the machine develops the forms we use to re...
# 4  As mentioned, first impressions can be mislead...
#
#                                                   gt
# 0  Chanting, the choir raised the volume as the c...
# 1  A six-month-old calf was submitted for examina...
# 2  Planning authorities should provide alternativ...
# 3  As the machine develops, the forms we use to r...
# 4  As mentioned first, impressions can be mislead...

# %%
translations = df['prediction']
ref_gem = df['gt']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 't5' Model:  0.8614563125151175

# %% [markdown]
# ## IndicTrans2 Sentences Meant

# %%
file_name = "sent_meant_outputs.csv"
mode="original_meant"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                                  src  \
# 0  Chanting, the choir raised the volume as the c...
# 1  A six-month-old calf was submitted for examina...
# 2  Planning authorities should provide alternativ...
# 3  As the machine develops, the forms we use to r...
# 4  As mentioned first, impressions can be mislead...
#
#                                           prediction  \
# 0  उत्सवी व्यक्तीने प्रार्थनेचा उच्चार करत असताना...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे यंत्र विकसित होईल तसतसे, मागील प्रकल्पां...
# 4  प्रथम नमूद केल्याप्रमाणे, छाप दिशाभूल करणारी अ...
#
#                                                   gt  \
# 0  जल्लोष करणाऱ्या व्यक्तीने प्रार्थनेचा उच्चार क...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे यंत्र विकसित होईल तसतसे, मागील प्रकल्पां...
# 4  आधी नमूद केल्याप्रमाणे, छाप दिशाभूल करणारी असू...
#
#                                               gemini  \
# 0  धर्मगुरू प्रार्थना म्हणत असताना, घोष करणाऱ्या ...
# 1  तपासणीसाठी आणलेल्या सहा महिन्यांच्या एका वासरा...
# 2  नियोजन प्राधिकरणांनी लहान व्यवसायांसाठी पर्याय...
# 3  जसजशी यंत्रणा विकसित होईल, तसतसे मागील प्रकल्प...
# 4    आधी सांगितल्याप्रमाणे, पहिली छाप फसवी असू शकते.
#
#                                                cfilt
# 0  उत्सवी प्रार्थनेचा उच्चार करत असताना, जप करत, ...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे मशीन विकसित होईल, तसतसे मागील प्रकल्पांम...
# 4  प्रथम नमूद केल्याप्रमाणे, छाप दिशाभूल करणारे अ...

# %%
translations = df['prediction']
ref_gem = df['gemini']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 'original_meant' Model:  0.29507197715617994

# %% [markdown]
# ## Cadence Approach1

# %%
file_name = "cadence_outputs.csv"
mode="cadence"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                                  src  \
# 0  Chanting the choir raised the volume as the ce...
# 1  A six-month-old calf was submitted for examina...
# 2  Planning authorities should provide alternativ...
# 3  As the machine develops the forms we use to re...
# 4  As mentioned, first impressions can be mislead...
#
#                                       prediction_mar  \
# 0  उत्सवी गायकांनी प्रार्थनेचा उच्चार केल्याने गा...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे मशीन विकसित होईल तसतसे आम्ही मागील प्रकल...
# 4  नमूद केल्याप्रमाणे, पहिली छाप दिशाभूल करणारी अ...
#
#                                               gt_mar
# 0  धर्मगुरू प्रार्थना म्हणत असताना, घोष करणाऱ्या ...
# 1  तपासणीसाठी आणलेल्या सहा महिन्यांच्या एका वासरा...
# 2  नियोजन प्राधिकरणांनी लहान व्यवसायांसाठी पर्याय...
# 3  जसजशी यंत्रणा विकसित होईल, तसतसे मागील प्रकल्प...
# 4    आधी सांगितल्याप्रमाणे, पहिली छाप फसवी असू शकते.

# %%
translations = df['prediction_mar']
ref_gem = df['gt_mar']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 'cadence' Model:  0.286757956293446

# %% [markdown]
# ## Cadence Punctuation Restoration

# %%
file_name = "approach1_eng_to_eng_cadence_outputs_punct_restor_data.csv"
mode="cadence_approach1"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                           prediction  \
# 0  Chanting the choir raised the volume as the ce...
# 1  A six-month-old calf was submitted for examina...
# 2  Planning authorities should provide alternativ...
# 3  As the machine develops the forms we use to re...
# 4  As mentioned, first impressions can be mislead...
#
#                                                  src  \
# 0  Chanting the choir raised the volume as the ce...
# 1  A six-month-old calf was submitted for examina...
# 2  Planning authorities should provide alternativ...
# 3  As the machine develops the forms we use to re...
# 4  As mentioned, first impressions can be mislead...
#
#                                                   gt
# 0  Chanting, the choir raised the volume as the c...
# 1  A six-month-old calf was submitted for examina...
# 2  Planning authorities should provide alternativ...
# 3  As the machine develops, the forms we use to r...
# 4  As mentioned first, impressions can be mislead...

# %%
translations = df['prediction']
ref_gem = df['gt']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 'cadence_approach1' Model:  0.8507522885446195

# %% [markdown]
# ## DeepSeek

# %%
file_name = "shalaka_deepseek_outputs.csv"
mode="deepseek"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                                  src  \
# 0  Chanting the choir raised the volume as the ce...
# 1  A six-month-old calf was submitted for examina...
# 2  Planning authorities should provide alternativ...
# 3  As the machine develops the forms we use to re...
# 4  As mentioned, first impressions can be mislead...
#
#                                           prediction  \
# 0  गायन करणारा गायनसमूह जसजशा उत्सवाध्यक्षाने प्र...
# 1  एका सहा-महिन्यांच्या वासरूची तपासणीसाठी सादर क...
# 2  नियोजन प्राधिकरणांनी लघुव्यवसायांसाठी पर्यायी ...
# 3  जसजशी मशीन विकसित होते, तसतसे मागील प्रकल्पांम...
# 4  जसे उल्लेख केला आहे, पहिल्या छापी गैरसमज निर्म...
#
#                                                indic  \
# 0  जल्लोष करणाऱ्या व्यक्तीने प्रार्थनेचा उच्चार क...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे यंत्र विकसित होईल तसतसे, मागील प्रकल्पां...
# 4  आधी नमूद केल्याप्रमाणे, छाप दिशाभूल करणारी असू...
#
#                                                   gt  \
# 0  धर्मगुरू प्रार्थना म्हणत असताना, घोष करणाऱ्या ...
# 1  तपासणीसाठी आणलेल्या सहा महिन्यांच्या एका वासरा...
# 2  नियोजन प्राधिकरणांनी लहान व्यवसायांसाठी पर्याय...
# 3  जसजशी यंत्रणा विकसित होईल, तसतसे मागील प्रकल्प...
# 4    आधी सांगितल्याप्रमाणे, पहिली छाप फसवी असू शकते.
#
#                                                cfilt
# 0  उत्सवी प्रार्थनेचा उच्चार करत असताना, जप करत, ...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे मशीन विकसित होईल, तसतसे मागील प्रकल्पांम...
# 4  प्रथम नमूद केल्याप्रमाणे, छाप दिशाभूल करणारे अ...

# %%
translations = df['prediction']
ref_gem = df['gt']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 'deepseek' Model:  0.26426545772011634

# %%
for key, val in bleurt.items():
    print(f"{key} : {val:.4f}")
# Out:
# cadence : 0.2868
# cadence_approach1 : 0.8508
# deepseek : 0.2643
