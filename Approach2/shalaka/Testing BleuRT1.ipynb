# %% [markdown]
# ! Please DONT Run this Notebook Directly... It changes all the Dependencies....
#
# Activate the Environment for BleuRT first

# %%
# import torch
# print(torch.__version__)

# %%
# import os
# print(os.getcwd())

# %cd bleurt

# %%
# !mkdir -p ./bleurt_checkpoints
# !wget -O ./bleurt_checkpoints/base-128.zip https://storage.googleapis.com/bleurt-oss/bleurt-base-128.zip
    
# !unzip ./bleurt_checkpoints/base-128.zip -d ./bleurt_checkpoints/base-128

# %%
import os
print(os.getcwd())
# Out:
# /workspace/Approach2/shalaka

# %%
from bleurt import score
scorer = score.BleurtScorer("./bleurt/bleurt_checkpoints/base-128/bleurt-base-128")
# Out:
# 2025-11-25 14:13:13.874721: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-25 14:13:13.939736: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-25 14:13:16.387138: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# INFO:tensorflow:Reading checkpoint ./bleurt/bleurt_checkpoints/base-128/bleurt-base-128.
# INFO:tensorflow:Config file found, reading.
# INFO:tensorflow:Will load checkpoint bert_custom
# INFO:tensorflow:Loads full paths and checks that files exists.
# INFO:tensorflow:... name:bert_custom
# INFO:tensorflow:... vocab_file:vocab.txt
# INFO:tensorflow:... bert_config_file:bert_config.json
# INFO:tensorflow:... do_lower_case:True
# INFO:tensorflow:... max_seq_length:128
# INFO:tensorflow:Creating BLEURT scorer.
# INFO:tensorflow:Creating WordPiece tokenizer.
# INFO:tensorflow:WordPiece tokenizer instantiated.
# INFO:tensorflow:Creating Eager Mode predictor.
# INFO:tensorflow:Loading model.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764080001.729572   49756 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20731 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:17:00.0, compute capability: 8.0
# I0000 00:00:1764080001.732297   49756 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 76400 MB memory:  -> device: 1, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:31:00.0, compute capability: 8.0
# I0000 00:00:1764080001.733817   49756 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 21892 MB memory:  -> device: 2, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:4b:00.0, compute capability: 8.0
# I0000 00:00:1764080001.735430   49756 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 47686 MB memory:  -> device: 3, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:ca:00.0, compute capability: 8.0
# INFO:tensorflow:BLEURT initialized.
# INFO:tensorflow:BLEURT initialized.

# %%
references = ["This is the test and done."]
candidates = ["This is the test."]

scores = scorer.score(references=references, candidates=candidates)
print(scores)

references = ["This is the test and done.", "abc, d"]
candidates = ["This is the test.", "abcd"]

scores = scorer.score(references=references, candidates=candidates)
print(scores)
# Out:
# [0.25093960762023926]
# [0.2506029009819031, -0.22334831953048706]

# %% [markdown]
# BLEURT does not have a fixed hard range like BLEU (0–100).
# But in practice, BLEURT scores fall roughly between –1.0 and 1.0 for most models.
#
# ✅ Practical BLEURT Score Range
#
# –1.0 → Very bad / unrelated translation
#
# 0.0 → Poor quality / weak similarity
#
# 0.3 – 0.6 → Decent / understandable
#
# 0.7 – 0.9 → Very good match
#
# 1.0+ → Almost identical (some checkpoints allow >1)
#
# Why no fixed range?
#
# BLEURT is a learned regression model trained to predict human judgments.
# Different checkpoints (BLEURT-tiny, BLEURT-base, dBLEURT, BLEURT-20, etc.) produce slightly different ranges.

# %%
from bleurt import score
import numpy as np

def compute_scores(preds, references):
    scores = scorer.score(candidates=preds, references=references)
    
    # Return corpus-level BLEURT as average
    return float(np.mean(scores))

# %%
import os
print(os.getcwd())
# Out:
# /workspace/Approach2/shalaka

# %%
scorer = score.BleurtScorer("./bleurt/bleurt_checkpoints/base-128/bleurt-base-128")
# Out:
# INFO:tensorflow:Reading checkpoint ./bleurt/bleurt_checkpoints/base-128/bleurt-base-128.
# INFO:tensorflow:Reading checkpoint ./bleurt/bleurt_checkpoints/base-128/bleurt-base-128.
# INFO:tensorflow:Config file found, reading.
# INFO:tensorflow:Config file found, reading.
# INFO:tensorflow:Will load checkpoint bert_custom
# INFO:tensorflow:Will load checkpoint bert_custom
# INFO:tensorflow:Loads full paths and checks that files exists.
# INFO:tensorflow:Loads full paths and checks that files exists.
# INFO:tensorflow:... name:bert_custom
# INFO:tensorflow:... name:bert_custom
# INFO:tensorflow:... vocab_file:vocab.txt
# INFO:tensorflow:... vocab_file:vocab.txt
# INFO:tensorflow:... bert_config_file:bert_config.json
# INFO:tensorflow:... bert_config_file:bert_config.json
# INFO:tensorflow:... do_lower_case:True
# INFO:tensorflow:... do_lower_case:True
# INFO:tensorflow:... max_seq_length:128
# INFO:tensorflow:... max_seq_length:128
# INFO:tensorflow:Creating BLEURT scorer.
# INFO:tensorflow:Creating BLEURT scorer.
# INFO:tensorflow:Creating WordPiece tokenizer.
# INFO:tensorflow:Creating WordPiece tokenizer.
# INFO:tensorflow:WordPiece tokenizer instantiated.
# INFO:tensorflow:WordPiece tokenizer instantiated.
# INFO:tensorflow:Creating Eager Mode predictor.
# INFO:tensorflow:Creating Eager Mode predictor.
# INFO:tensorflow:Loading model.
# INFO:tensorflow:Loading model.
# INFO:tensorflow:BLEURT initialized.
# INFO:tensorflow:BLEURT initialized.

# %%
bleurt = {}

# %% [markdown]
# ## Original

# %%
file_name = "shalaka_original_outputs.csv"
mode="original"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                                  src  \
# 0  Chanting the choir raised the volume as the ce...
# 1  A six-month-old calf was submitted for examina...
# 2  Planning authorities should provide alternativ...
# 3  As the machine develops the forms we use to re...
# 4  As mentioned, first impressions can be mislead...
#
#                                           prediction  \
# 0  उत्सवी गायकांनी प्रार्थनेचा उच्चार केल्याने गा...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे मशीन विकसित होईल तसतसे आम्ही मागील प्रकल...
# 4  नमूद केल्याप्रमाणे, पहिली छाप दिशाभूल करणारी अ...
#
#                                                   gt  \
# 0  जल्लोष करणाऱ्या व्यक्तीने प्रार्थनेचा उच्चार क...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे यंत्र विकसित होईल तसतसे, मागील प्रकल्पां...
# 4  आधी नमूद केल्याप्रमाणे, छाप दिशाभूल करणारी असू...
#
#                                               gemini  \
# 0  धर्मगुरू प्रार्थना म्हणत असताना, घोष करणाऱ्या ...
# 1  तपासणीसाठी आणलेल्या सहा महिन्यांच्या एका वासरा...
# 2  नियोजन प्राधिकरणांनी लहान व्यवसायांसाठी पर्याय...
# 3  जसजशी यंत्रणा विकसित होईल, तसतसे मागील प्रकल्प...
# 4    आधी सांगितल्याप्रमाणे, पहिली छाप फसवी असू शकते.
#
#                                                cfilt
# 0  उत्सवी प्रार्थनेचा उच्चार करत असताना, जप करत, ...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे मशीन विकसित होईल, तसतसे मागील प्रकल्पांम...
# 4  प्रथम नमूद केल्याप्रमाणे, छाप दिशाभूल करणारे अ...

# %%
translations = df['prediction']
ref_gt = df['gt']
ref_gem = df['gemini']
ref_cfilt = df['cfilt']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 'original' Model:  0.2730780980653233

# %% [markdown]
# ## Only Punctuations

# %%
file_name = "shalaka_only_punct_outputs.csv"
mode="only_punct"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                                  src  \
# 0  Chanting the choir raised the volume as the ce...
# 1  A six-month-old calf was submitted for examina...
# 2  Planning authorities should provide alternativ...
# 3  As the machine develops the forms we use to re...
# 4  As mentioned, first impressions can be mislead...
#
#                                           prediction  \
# 0  उत्सव साजरा करणार\u093C्याने प्रार्थना केली ते...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन प्राधिकरणांनी निवासी क्षेत्रात आक्षेपार...
# 3  जसजसे मशीन विकसित होईल तसतसे आम्ही मागील प्रकल...
# 4     नमूद केल्याप्रमाणे, पहिली छाप भ्रामक असू शकते.
#
#                                                   gt  \
# 0  जल्लोष करणाऱ्या व्यक्तीने प्रार्थनेचा उच्चार क...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे यंत्र विकसित होईल तसतसे, मागील प्रकल्पां...
# 4  आधी नमूद केल्याप्रमाणे, छाप दिशाभूल करणारी असू...
#
#                                               gemini  \
# 0  धर्मगुरू प्रार्थना म्हणत असताना, घोष करणाऱ्या ...
# 1  तपासणीसाठी आणलेल्या सहा महिन्यांच्या एका वासरा...
# 2  नियोजन प्राधिकरणांनी लहान व्यवसायांसाठी पर्याय...
# 3  जसजशी यंत्रणा विकसित होईल, तसतसे मागील प्रकल्प...
# 4    आधी सांगितल्याप्रमाणे, पहिली छाप फसवी असू शकते.
#
#                                                cfilt
# 0  उत्सवी प्रार्थनेचा उच्चार करत असताना, जप करत, ...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे मशीन विकसित होईल, तसतसे मागील प्रकल्पांम...
# 4  प्रथम नमूद केल्याप्रमाणे, छाप दिशाभूल करणारे अ...

# %%
translations = df['prediction']
ref_gt = df['gt']
ref_gem = df['gemini']
ref_cfilt = df['cfilt']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 'only_punct' Model:  0.2453651417184759

# %% [markdown]
# ## Without Punctuations

# %%
file_name = "shalaka_without_punct_outputs.csv"
mode="without_punct"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                                  src  \
# 0  Chanting the choir raised the volume as the ce...
# 1  A six-month-old calf was submitted for examina...
# 2  Planning authorities should provide alternativ...
# 3  As the machine develops the forms we use to re...
# 4  As mentioned, first impressions can be mislead...
#
#                                           prediction  \
# 0  उत्सव साजरा करणार\u093C्याने प्रार्थनेचा उच्चा...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या सर्व चारही...
# 2  नियोजन प्राधिकरणांनी छोट्या व्यवसायांसाठी पर्य...
# 3  जसजसे मशीन विकसित होते, तसतसे आपण मागील प्रकल्...
# 4     नमूद केल्याप्रमाणे, पहिली छाप भ्रामक असू शकते.
#
#                                                   gt  \
# 0  जल्लोष करणाऱ्या व्यक्तीने प्रार्थनेचा उच्चार क...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे यंत्र विकसित होईल तसतसे, मागील प्रकल्पां...
# 4  आधी नमूद केल्याप्रमाणे, छाप दिशाभूल करणारी असू...
#
#                                               gemini  \
# 0  धर्मगुरू प्रार्थना म्हणत असताना, घोष करणाऱ्या ...
# 1  तपासणीसाठी आणलेल्या सहा महिन्यांच्या एका वासरा...
# 2  नियोजन प्राधिकरणांनी लहान व्यवसायांसाठी पर्याय...
# 3  जसजशी यंत्रणा विकसित होईल, तसतसे मागील प्रकल्प...
# 4    आधी सांगितल्याप्रमाणे, पहिली छाप फसवी असू शकते.
#
#                                                cfilt
# 0  उत्सवी प्रार्थनेचा उच्चार करत असताना, जप करत, ...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे मशीन विकसित होईल, तसतसे मागील प्रकल्पांम...
# 4  प्रथम नमूद केल्याप्रमाणे, छाप दिशाभूल करणारे अ...

# %%
translations = df['prediction']
ref_gt = df['gt']
ref_gem = df['gemini']
ref_cfilt = df['cfilt']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 'without_punct' Model:  0.259856477310812

# %% [markdown]
# ## Combined

# %%
file_name = "shalaka_combined_outputs.csv"
mode="combined"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                                  src  \
# 0  Chanting the choir raised the volume as the ce...
# 1  A six-month-old calf was submitted for examina...
# 2  Planning authorities should provide alternativ...
# 3  As the machine develops the forms we use to re...
# 4  As mentioned, first impressions can be mislead...
#
#                                           prediction  \
# 0  उत्सव साजरा करणार\u093C्याने प्रार्थनेचा सूर व...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकार\u093C्यांनी छोट्या व्यवसायांसाठी...
# 3  जसजसे मशीन विकसित होईल तसतसे आपण मागील प्रकल्प...
# 4  नमूद केल्याप्रमाणे, पहिली छाप दिशाभूल करणारी अ...
#
#                                                   gt  \
# 0  जल्लोष करणाऱ्या व्यक्तीने प्रार्थनेचा उच्चार क...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे यंत्र विकसित होईल तसतसे, मागील प्रकल्पां...
# 4  आधी नमूद केल्याप्रमाणे, छाप दिशाभूल करणारी असू...
#
#                                               gemini  \
# 0  धर्मगुरू प्रार्थना म्हणत असताना, घोष करणाऱ्या ...
# 1  तपासणीसाठी आणलेल्या सहा महिन्यांच्या एका वासरा...
# 2  नियोजन प्राधिकरणांनी लहान व्यवसायांसाठी पर्याय...
# 3  जसजशी यंत्रणा विकसित होईल, तसतसे मागील प्रकल्प...
# 4    आधी सांगितल्याप्रमाणे, पहिली छाप फसवी असू शकते.
#
#                                                cfilt
# 0  उत्सवी प्रार्थनेचा उच्चार करत असताना, जप करत, ...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे मशीन विकसित होईल, तसतसे मागील प्रकल्पांम...
# 4  प्रथम नमूद केल्याप्रमाणे, छाप दिशाभूल करणारे अ...

# %%
translations = df['prediction']
ref_gt = df['gt']
ref_gem = df['gemini']
ref_cfilt = df['cfilt']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 'combined' Model:  0.2759865912160388

# %% [markdown]
# ## Combined- Shalaka LR=5e-6 Epochs=3

# %%
file_name = "shalaka_combined_le_outputs.csv"
mode="combined_le"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                                  src  \
# 0  Chanting the choir raised the volume as the ce...
# 1  A six-month-old calf was submitted for examina...
# 2  Planning authorities should provide alternativ...
# 3  As the machine develops the forms we use to re...
# 4  As mentioned, first impressions can be mislead...
#
#                                           prediction  \
# 0  उत्सव साजरा करणार\u093C्याने प्रार्थनेचा उच्चा...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकार\u093C्यांनी छोट्या व्यवसायांसाठी...
# 3  जसजसे मशीन विकसित होईल तसतसे मागील प्रकल्पांमध...
# 4  नमूद केल्याप्रमाणे, पहिली छाप दिशाभूल करणारी अ...
#
#                                                   gt  \
# 0  जल्लोष करणाऱ्या व्यक्तीने प्रार्थनेचा उच्चार क...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे यंत्र विकसित होईल तसतसे, मागील प्रकल्पां...
# 4  आधी नमूद केल्याप्रमाणे, छाप दिशाभूल करणारी असू...
#
#                                               gemini  \
# 0  धर्मगुरू प्रार्थना म्हणत असताना, घोष करणाऱ्या ...
# 1  तपासणीसाठी आणलेल्या सहा महिन्यांच्या एका वासरा...
# 2  नियोजन प्राधिकरणांनी लहान व्यवसायांसाठी पर्याय...
# 3  जसजशी यंत्रणा विकसित होईल, तसतसे मागील प्रकल्प...
# 4    आधी सांगितल्याप्रमाणे, पहिली छाप फसवी असू शकते.
#
#                                                cfilt
# 0  उत्सवी प्रार्थनेचा उच्चार करत असताना, जप करत, ...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे मशीन विकसित होईल, तसतसे मागील प्रकल्पांम...
# 4  प्रथम नमूद केल्याप्रमाणे, छाप दिशाभूल करणारे अ...

# %%
translations = df['prediction']
ref_gt = df['gt']
ref_gem = df['gemini']
ref_cfilt = df['cfilt']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 'combined_le' Model:  0.27357398070119043

# %% [markdown]
# ## Combined- Shalaka LR=5e-6 Epochs=3 Changed Dataset

# %%
file_name = "shalaka_combined_led_outputs.csv"
mode="combined_led"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                                  src  \
# 0  Chanting the choir raised the volume as the ce...
# 1  A six-month-old calf was submitted for examina...
# 2  Planning authorities should provide alternativ...
# 3  As the machine develops the forms we use to re...
# 4  As mentioned, first impressions can be mislead...
#
#                                           prediction  \
# 0  उत्सव साजरा करणार\u093C्याने प्रार्थनेचा उच्चा...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकार\u093C्यांनी छोट्या व्यवसायांसाठी...
# 3  जसजसे मशीन विकसित होईल तसतसे मागील प्रकल्पांमध...
# 4  नमूद केल्याप्रमाणे, पहिली छाप दिशाभूल करणारी अ...
#
#                                                   gt  \
# 0  जल्लोष करणाऱ्या व्यक्तीने प्रार्थनेचा उच्चार क...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे यंत्र विकसित होईल तसतसे, मागील प्रकल्पां...
# 4  आधी नमूद केल्याप्रमाणे, छाप दिशाभूल करणारी असू...
#
#                                               gemini  \
# 0  धर्मगुरू प्रार्थना म्हणत असताना, घोष करणाऱ्या ...
# 1  तपासणीसाठी आणलेल्या सहा महिन्यांच्या एका वासरा...
# 2  नियोजन प्राधिकरणांनी लहान व्यवसायांसाठी पर्याय...
# 3  जसजशी यंत्रणा विकसित होईल, तसतसे मागील प्रकल्प...
# 4    आधी सांगितल्याप्रमाणे, पहिली छाप फसवी असू शकते.
#
#                                                cfilt
# 0  उत्सवी प्रार्थनेचा उच्चार करत असताना, जप करत, ...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे मशीन विकसित होईल, तसतसे मागील प्रकल्पांम...
# 4  प्रथम नमूद केल्याप्रमाणे, छाप दिशाभूल करणारे अ...

# %%
translations = df['prediction']
ref_gt = df['gt']
ref_gem = df['gemini']
ref_cfilt = df['cfilt']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 'combined_led' Model:  0.2528066448867321

# %% [markdown]
# ## GPT-5

# %%
file_name = "shalaka_gpt_outputs.csv"
mode="gpt"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                                  src  \
# 0  Chanting the choir raised the volume as the ce...
# 1  A six-month-old calf was submitted for examina...
# 2  Planning authorities should provide alternativ...
# 3  As the machine develops the forms we use to re...
# 4  As mentioned, first impressions can be mislead...
#
#                                           prediction  \
# 0  मंडळातील गायन करताना गायकांचा आवाज वाढवला गेला...
# 1  सहा महिन्यांचा बछडा तपासणीसाठी सादर केला गेला,...
# 2  नियोजन प्राधिकरणांनी अशा लघु व्यवसायांसाठी पर्...
# 3  मशीन जसे स्वरूप विकसित करते, तसेच आपण भूतपूर्व...
# 4            जसे म्हटले, पहिले छाप चुकीचे ठरू शकतात.
#
#                                                   gt  \
# 0  जल्लोष करणाऱ्या व्यक्तीने प्रार्थनेचा उच्चार क...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे यंत्र विकसित होईल तसतसे, मागील प्रकल्पां...
# 4  आधी नमूद केल्याप्रमाणे, छाप दिशाभूल करणारी असू...
#
#                                               gemini  \
# 0  धर्मगुरू प्रार्थना म्हणत असताना, घोष करणाऱ्या ...
# 1  तपासणीसाठी आणलेल्या सहा महिन्यांच्या एका वासरा...
# 2  नियोजन प्राधिकरणांनी लहान व्यवसायांसाठी पर्याय...
# 3  जसजशी यंत्रणा विकसित होईल, तसतसे मागील प्रकल्प...
# 4    आधी सांगितल्याप्रमाणे, पहिली छाप फसवी असू शकते.
#
#                                                cfilt
# 0  उत्सवी प्रार्थनेचा उच्चार करत असताना, जप करत, ...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे मशीन विकसित होईल, तसतसे मागील प्रकल्पांम...
# 4  प्रथम नमूद केल्याप्रमाणे, छाप दिशाभूल करणारे अ...

# %%
translations = df['prediction']
ref_gt = df['gt']
ref_gem = df['gemini']
ref_cfilt = df['cfilt']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 'gpt' Model:  0.18298462302320534

# %% [markdown]
# ## BERT

# %%
file_name = "approach1_bert_outputs.csv"
mode="beart"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                                  src  \
# 0  Chanting: the choir raised the volume as the c...
# 1  A six-month-old calf was submitted for examina...
# 2  Planning authorities should provide alternativ...
# 3  As the machine develops, the forms we use to r...
# 4  As mentioned,, first impressions can be mislea...
#
#                                           prediction  \
# 0  जपः गायकवृंदाने आवाज वाढवला आणि उत्सवी व्यक्ती...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे यंत्र विकसित होईल तसतसे, मागील प्रकल्पां...
# 4  नमूद केल्याप्रमाणे, पहिली छाप दिशाभूल करणारी अ...
#
#                                                   gt  \
# 0  जल्लोष करणाऱ्या व्यक्तीने प्रार्थनेचा उच्चार क...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे यंत्र विकसित होईल तसतसे, मागील प्रकल्पां...
# 4  आधी नमूद केल्याप्रमाणे, छाप दिशाभूल करणारी असू...
#
#                                               gemini  \
# 0  धर्मगुरू प्रार्थना म्हणत असताना, घोष करणाऱ्या ...
# 1  तपासणीसाठी आणलेल्या सहा महिन्यांच्या एका वासरा...
# 2  नियोजन प्राधिकरणांनी लहान व्यवसायांसाठी पर्याय...
# 3  जसजशी यंत्रणा विकसित होईल, तसतसे मागील प्रकल्प...
# 4    आधी सांगितल्याप्रमाणे, पहिली छाप फसवी असू शकते.
#
#                                                cfilt
# 0  उत्सवी प्रार्थनेचा उच्चार करत असताना, जप करत, ...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे मशीन विकसित होईल, तसतसे मागील प्रकल्पांम...
# 4  प्रथम नमूद केल्याप्रमाणे, छाप दिशाभूल करणारे अ...

# %%
translations = df['prediction']
ref_gt = df['gt']
ref_gem = df['gemini']
ref_cfilt = df['cfilt']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 'beart' Model:  0.2957495902147558

# %% [markdown]
# ## MPNet

# %%
file_name = "approach1_mpnet_outputs.csv"
mode="mpnet"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                                  src  \
# 0  Chanting, the choir raised the volume as the c...
# 1  A six-month-- old calf was submitted for exami...
# 2  Planning authorities should provide alternativ...
# 3  As the machine develops, the forms we use to r...
# 4  As mentioned,, first impressions can be mislea...
#
#                                           prediction  \
# 0  उत्सवी व्यक्तीने प्रार्थनेचा उच्चार करत असताना...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे यंत्र विकसित होईल तसतसे, मागील प्रकल्पां...
# 4  नमूद केल्याप्रमाणे, पहिली छाप दिशाभूल करणारी अ...
#
#                                                   gt  \
# 0  जल्लोष करणाऱ्या व्यक्तीने प्रार्थनेचा उच्चार क...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे यंत्र विकसित होईल तसतसे, मागील प्रकल्पां...
# 4  आधी नमूद केल्याप्रमाणे, छाप दिशाभूल करणारी असू...
#
#                                               gemini  \
# 0  धर्मगुरू प्रार्थना म्हणत असताना, घोष करणाऱ्या ...
# 1  तपासणीसाठी आणलेल्या सहा महिन्यांच्या एका वासरा...
# 2  नियोजन प्राधिकरणांनी लहान व्यवसायांसाठी पर्याय...
# 3  जसजशी यंत्रणा विकसित होईल, तसतसे मागील प्रकल्प...
# 4    आधी सांगितल्याप्रमाणे, पहिली छाप फसवी असू शकते.
#
#                                                cfilt
# 0  उत्सवी प्रार्थनेचा उच्चार करत असताना, जप करत, ...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे मशीन विकसित होईल, तसतसे मागील प्रकल्पांम...
# 4  प्रथम नमूद केल्याप्रमाणे, छाप दिशाभूल करणारे अ...

# %%
translations = df['prediction']
ref_gt = df['gt']
ref_gem = df['gemini']
ref_cfilt = df['cfilt']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 'mpnet' Model:  0.28470377327391394

# %% [markdown]
# ## T5

# %%
file_name = "approach1_t5_outputs.csv"
mode="t5"

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                                                  src  \
# 0  Chanting, the choir raised the volume as the c...
# 1  A six-month-old calf was submitted for examina...
# 2  Planning authorities should provide alternativ...
# 3  As the machine develops, the forms we use to r...
# 4  As mentioned, first impressions can be mislead...
#
#                                           prediction  \
# 0  उत्सवी व्यक्तीने प्रार्थनेचा उच्चार करत असताना...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे यंत्र विकसित होईल तसतसे, मागील प्रकल्पां...
# 4  नमूद केल्याप्रमाणे, पहिली छाप दिशाभूल करणारी अ...
#
#                                                   gt  \
# 0  जल्लोष करणाऱ्या व्यक्तीने प्रार्थनेचा उच्चार क...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे यंत्र विकसित होईल तसतसे, मागील प्रकल्पां...
# 4  आधी नमूद केल्याप्रमाणे, छाप दिशाभूल करणारी असू...
#
#                                               gemini  \
# 0  धर्मगुरू प्रार्थना म्हणत असताना, घोष करणाऱ्या ...
# 1  तपासणीसाठी आणलेल्या सहा महिन्यांच्या एका वासरा...
# 2  नियोजन प्राधिकरणांनी लहान व्यवसायांसाठी पर्याय...
# 3  जसजशी यंत्रणा विकसित होईल, तसतसे मागील प्रकल्प...
# 4    आधी सांगितल्याप्रमाणे, पहिली छाप फसवी असू शकते.
#
#                                                cfilt
# 0  उत्सवी प्रार्थनेचा उच्चार करत असताना, जप करत, ...
# 1  जन्मानंतर लगेचच अस्तित्वात असलेल्या चारही पाया...
# 2  नियोजन अधिकाऱ्यांनी छोट्या व्यवसायांसाठी पर्या...
# 3  जसजसे मशीन विकसित होईल, तसतसे मागील प्रकल्पांम...
# 4  प्रथम नमूद केल्याप्रमाणे, छाप दिशाभूल करणारे अ...

# %%
translations = df['prediction']
ref_gt = df['gt']
ref_gem = df['gemini']
ref_cfilt = df['cfilt']

# %%
bleurt_score = compute_scores(translations, ref_gem)
bleurt[mode] = bleurt_score
print(f"BleuRT Score for '{mode}' Model: ", bleurt_score)
# Out:
# BleuRT Score for 't5' Model:  0.29091422632336617

# %%
for key, val in bleurt.items():
    print(f"{key} : {val:.4f}")
# Out:
# original : 0.2731
# only_punct : 0.2454
# without_punct : 0.2599
# combined : 0.2760
# combined_le : 0.2736
# combined_led : 0.2528
# gpt : 0.1830
# beart : 0.2957
# mpnet : 0.2847
# t5 : 0.2909
